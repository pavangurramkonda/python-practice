# %%
## Definining Variables and Printing Them ##
name = "Pavan"
Name="Gurramkonda" #name and Name are different variables. python is case-sensitive.
age = 40
height = 5.9
print ("My name is ", name, "My last name is ", Name, "My age is ", age, "My height is ", height)
# Out:
# My name is  Pavan My last name is  Gurramkonda My age is  40 My height is  5.9

# %%
age = 40
height = 5.9
is_student = True
print(type(age), type(height), type(is_student))
# Out:
# <class 'int'> <class 'float'> <class 'bool'>
# My age is 40
# <class 'str'>

# %%
#Type conversion from integer to srting example
age_str = str(age)
print("My age is " + age_str)
print(type(age_str))
height_int = int(height)
print("My height is " + str(height_int))
# Out:
# My age is 40
# <class 'str'>
# My height is 5

# %%
## Dynamc Typing in Python ##
var = 10
print("Value:", var, "Type:", type(var))
var = "Hello"
print("Value:", var, "Type:", type(var))
var = 5.5
print("Value:", var, "Type:", type(var))
# Out:
# Value: 10 Type: <class 'int'>
# Value: Hello Type: <class 'str'>
# Value: 5.5 Type: <class 'float'>

# %%
age = input("What is your age?")
print("Your age is ", age)
if int(age) < 35:
    print("Your age is less than 35")
if int(age)>50:
    print("You have become old")
# Out:
# Your age is  8950
# You have become old

# %%
num1 = int(input("enter first number"))
num2= int(input("enter second number"))
sum = num1 + num2
difference = num1 - num2
Product = num1 * num2
Quotient = num1 / num2
print("Sum:", sum)
print("Difference:", difference)
print("Product:", Product)
print("Quotient:", Quotient)
# Out:
# Sum: 154
# Difference: -24
# Product: 5785
# Quotient: 0.7303370786516854

# %%
Word = "Hello"
age = 25
print (Word +" "+ str(age))
# Out:
# Hello 25

# %%
# Your code here
x = int(input("Enter a number: "))
y=x
factorial = 1
while x > 1:
    factorial *= x
    x -= 1
print("The factorial of", y, "is", factorial)
# Out:
# The factorial of 4 is 24
