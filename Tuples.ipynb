# %% [markdown]
# Tuple is immutable, unlike lists. We use () in tuples and [] in lists.

# %%
empty_tuple=()
print(type(empty_tuple))

# %%
numbers = (5, 2, 9, 1, 5, 6)
print(type(numbers))

numbers_list= list((1,2,3,4,5))
print(type(numbers_list))

print(numbers[2])
print(numbers[0:5])
numbers

# %%
set1 = {1,2,3,4,5}
set2 = {4,5,6,7,8}
union_set = set1.union(set2)
##print(f"Union of set1 and set2 is {union_set}")
intersection_set=set1.intersection(set2)
print(f"Intersection of set1 and set2 is {intersection_set}")
# Out:
# Intersection of set1 and set2 is {4, 5}

# %%
##

# %%
mixed_tuple = (1, "hello world", 3.14, True)
concatinate_tuple = numbers + mixed_tuple
print(concatinate_tuple)
